# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
plt.style.use('seaborn-v0_8')

# %%
from pandas import Series, DataFrame
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv('/Users/anilthapa/Documents/Datasets/cell_samples.csv')
df.shape
# Out:
# (699, 11)

# %%
df.head()
# Out:
#         ID  Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  \
# 0  1000025      5         1          1        1            2       1
# 1  1002945      5         4          4        5            7      10
# 2  1015425      3         1          1        1            2       2
# 3  1016277      6         8          8        1            3       4
# 4  1017023      4         1          1        3            2       1
#
#    BlandChrom  NormNucl  Mit  Class
# 0           3         1    1      2
# 1           3         2    1      2
# 2           3         1    1      2
# 3           3         7    1      2
# 4           3         1    1      2

# %%
df.isnull().any()
# Out:
# ID             False
# Clump          False
# UnifSize       False
# UnifShape      False
# MargAdh        False
# SingEpiSize    False
# BareNuc        False
# BlandChrom     False
# NormNucl       False
# Mit            False
# Class          False
# dtype: bool

# %% [markdown]
# There are no null values. Good thing for us.
# Later we found out that the null value were present in `BareNuc` columns as `?` as place holder

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           699 non-null    int64
#  1   Clump        699 non-null    int64
#  2   UnifSize     699 non-null    int64
#  3   UnifShape    699 non-null    int64
#  4   MargAdh      699 non-null    int64
#  5   SingEpiSize  699 non-null    int64
#  6   BareNuc      699 non-null    object
#  7   BlandChrom   699 non-null    int64
#  8   NormNucl     699 non-null    int64
#  9   Mit          699 non-null    int64
#  10  Class        699 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB

# %% [markdown]
# Now, we convert the column 6 which is listed as object into int64

# %%
df.replace('?', np.nan, inplace=True)

# %%
df.isnull().any()
# Out:
# ID             False
# Clump          False
# UnifSize       False
# UnifShape      False
# MargAdh        False
# SingEpiSize    False
# BareNuc         True
# BlandChrom     False
# NormNucl       False
# Mit            False
# Class          False
# dtype: bool

# %%
df.isnull().any().count()
# Out:
# 11

# %%
df.dropna(inplace=True)

# %%
df.isnull().any()
# Out:
# ID             False
# Clump          False
# UnifSize       False
# UnifShape      False
# MargAdh        False
# SingEpiSize    False
# BareNuc        False
# BlandChrom     False
# NormNucl       False
# Mit            False
# Class          False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 683 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           683 non-null    int64
#  1   Clump        683 non-null    int64
#  2   UnifSize     683 non-null    int64
#  3   UnifShape    683 non-null    int64
#  4   MargAdh      683 non-null    int64
#  5   SingEpiSize  683 non-null    int64
#  6   BareNuc      683 non-null    object
#  7   BlandChrom   683 non-null    int64
#  8   NormNucl     683 non-null    int64
#  9   Mit          683 non-null    int64
#  10  Class        683 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 64.0+ KB

# %% [markdown]
# Now, we convert the BareNuc column as object into int64 as other colums

# %%
df['BareNuc'] = df['BareNuc'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 683 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           683 non-null    int64
#  1   Clump        683 non-null    int64
#  2   UnifSize     683 non-null    int64
#  3   UnifShape    683 non-null    int64
#  4   MargAdh      683 non-null    int64
#  5   SingEpiSize  683 non-null    int64
#  6   BareNuc      683 non-null    int64
#  7   BlandChrom   683 non-null    int64
#  8   NormNucl     683 non-null    int64
#  9   Mit          683 non-null    int64
#  10  Class        683 non-null    int64
# dtypes: int64(11)
# memory usage: 64.0 KB

# %%
df.drop('ID', axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 683 entries, 0 to 698
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Clump        683 non-null    int64
#  1   UnifSize     683 non-null    int64
#  2   UnifShape    683 non-null    int64
#  3   MargAdh      683 non-null    int64
#  4   SingEpiSize  683 non-null    int64
#  5   BareNuc      683 non-null    int64
#  6   BlandChrom   683 non-null    int64
#  7   NormNucl     683 non-null    int64
#  8   Mit          683 non-null    int64
#  9   Class        683 non-null    int64
# dtypes: int64(10)
# memory usage: 58.7 KB

# %%
df.head()
# Out:
#    Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BareNuc  BlandChrom  \
# 0      5         1          1        1            2        1           3
# 1      5         4          4        5            7       10           3
# 2      3         1          1        1            2        2           3
# 3      6         8          8        1            3        4           3
# 4      4         1          1        3            2        1           3
#
#    NormNucl  Mit  Class
# 0         1    1      2
# 1         2    1      2
# 2         1    1      2
# 3         7    1      2
# 4         1    1      2

# %%
df.describe()
# Out:
#             Clump    UnifSize   UnifShape     MargAdh  SingEpiSize  \
# count  683.000000  683.000000  683.000000  683.000000   683.000000
# mean     4.442167    3.150805    3.215227    2.830161     3.234261
# std      2.820761    3.065145    2.988581    2.864562     2.223085
# min      1.000000    1.000000    1.000000    1.000000     1.000000
# 25%      2.000000    1.000000    1.000000    1.000000     2.000000
# 50%      4.000000    1.000000    1.000000    1.000000     2.000000
# 75%      6.000000    5.000000    5.000000    4.000000     4.000000
# max     10.000000   10.000000   10.000000   10.000000    10.000000
#
#           BareNuc  BlandChrom    NormNucl         Mit       Class
# count  683.000000  683.000000  683.000000  683.000000  683.000000
# mean     3.544656    3.445095    2.869693    1.603221    2.699854
# std      3.643857    2.449697    3.052666    1.732674    0.954592
# min      1.000000    1.000000    1.000000    1.000000    2.000000
# ...

# %%
df
# Out:
#      Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BareNuc  BlandChrom  \
# 0        5         1          1        1            2        1           3
# 1        5         4          4        5            7       10           3
# 2        3         1          1        1            2        2           3
# 3        6         8          8        1            3        4           3
# 4        4         1          1        3            2        1           3
# ..     ...       ...        ...      ...          ...      ...         ...
# 694      3         1          1        1            3        2           1
# 695      2         1          1        1            2        1           1
# 696      5        10         10        3            7        3           8
# 697      4         8          6        4            3        4          10
# 698      4         8          8        5            4        5          10
#
#      NormNucl  Mit  Class
# 0           1    1      2
# ...

# %%
df.shape
# Out:
# (683, 10)

# %%
sns.heatmap(df.corr(), cmap='Blues', annot=True)
# Out:
# <Axes: >

# %%
X = df[['Clump', 'UnifSize', 'UnifShape', 'MargAdh', 'SingEpiSize', 'BareNuc',
       'BlandChrom', 'NormNucl', 'Mit']]
y = df['Class']
# Out:
#      Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BareNuc  BlandChrom  \
# 0        5         1          1        1            2        1           3
# 1        5         4          4        5            7       10           3
# 2        3         1          1        1            2        2           3
# 3        6         8          8        1            3        4           3
# 4        4         1          1        3            2        1           3
# ..     ...       ...        ...      ...          ...      ...         ...
# 694      3         1          1        1            3        2           1
# 695      2         1          1        1            2        1           1
# 696      5        10         10        3            7        3           8
# 697      4         8          6        4            3        4          10
# 698      4         8          8        5            4        5          10
#
#      NormNucl  Mit
# 0           1    1
# 1           2    1
# ...

# %%
features = X.columns

# %%
fig, ax = plt.subplots(nrows=9, ncols=1, figsize = (6,14))
for i, feature in enumerate(features):
    sns.boxplot(X[feature], orient = 'h', ax =ax[i])
    
plt.tight_layout()
plt.show()

# %%
features = ['Clump', 'UnifSize', 'UnifShape', 'MargAdh', 'SingEpiSize', 'BareNuc',
       'BlandChrom', 'NormNucl', 'Mit', 'Class']

# %%
fig, ax = plt.subplots(nrows=5, ncols=2, figsize = (8,16))
ax = ax.flatten()
for i, feature in enumerate(features):
    sns.kdeplot(df[feature],fill=True, alpha = 0.7, ax = ax[i])
plt.tight_layout()
plt.show()

# %%
X = df[['Clump', 'UnifSize', 'UnifShape', 'MargAdh', 'SingEpiSize', 'BareNuc',
       'BlandChrom', 'NormNucl', 'Mit']]
y = df['Class']

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 42)

# %%
svc = SVC(kernel='rbf')
tree = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_predict = svc.predict(X_test)

# %%
print('Metrics:')
print('Accuracy Score:', accuracy_score(y_predict, y_test))
print(classification_report(y_predict, y_test))
# Out:
# Metrics:
# Accuracy Score: 0.9635036496350365
#               precision    recall  f1-score   support
#
#            2       0.97      0.96      0.97        80
#            4       0.95      0.96      0.96        57
#
#     accuracy                           0.96       137
#    macro avg       0.96      0.96      0.96       137
# weighted avg       0.96      0.96      0.96       137
