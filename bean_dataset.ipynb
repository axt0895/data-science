# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pandas import Series, DataFrame
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split

# %%
bean = pd.read_excel('/Users/anilthapa/Documents/Datasets/Dry_Bean_Dataset.xlsx')

# %%
bean.shape
# Out:
# (13611, 17)

# %%
bean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
bean.head(n =10)
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
# 5  30279    634.927       212.560556       181.510182      1.171067
# 6  30477    670.033       211.050155       184.039050      1.146768
# 7  30519    629.727       212.996755       182.737204      1.165591
# 8  30685    635.681       213.534145       183.157146      1.165852
# 9  30834    631.934       217.227813       180.897469      1.200834
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# ...

# %%
bean['Class'].unique()
# Out:
# array(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'],
#       dtype=object)

# %%
label_encoder = LabelEncoder()
encoded_Class = label_encoder.fit_transform(bean['Class'])
encoded_Class
# Out:
# array([5, 5, 5, ..., 3, 3, 3])

# %%
bean['encoded_class']= Series.values

# %%
bean.drop('encoded_class', axis = 1)
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
bean['encoded_class'] = DataFrame(encoded_Class)

# %%
bean.drop('Class', axis = 1, inplace=True)

# %%
bean
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
bean.columns
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4', 'encoded_class'],
#       dtype='object')

# %%
standard_scaler = StandardScaler()

# %%
X = bean[['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
       'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
       'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
       'ShapeFactor3', 'ShapeFactor4']]
y = bean['encoded_class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75)

# %%
X_train_scaled = standard_scaler.fit_transform(X_train)

# %%
X_train
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 13172  38091    755.186       271.077683       179.756984      1.508023
# 10172  23980    575.605       204.749520       149.430765      1.370197
# 10960  28584    625.161       232.767486       156.572708      1.486642
# 65     32581    649.583       224.424178       184.923471      1.213606
# 6400   53174    904.614       361.914574       189.074605      1.914136
# ...      ...        ...              ...              ...           ...
# 982    39037    712.794       250.782231       198.444192      1.263742
# 13414  39814    740.266       278.435684       182.381665      1.526665
# 10029  55314    896.530       343.568669       205.981740      1.667957
# 8008   41201    770.513       283.139922       186.387386      1.519094
# 4536   72814   1044.679       404.769656       232.095506      1.743979
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
X_train_scaled
# Out:
# array([[-0.51159071, -0.47039546, -0.57368488, ...,  0.32878877,
#          0.1608251 ,  0.04992256],
#        [-0.98810887, -1.30335453, -1.34377195, ...,  1.80660549,
#          0.8515856 ,  0.65215452],
#        [-0.83263515, -1.07349659, -1.01847614, ...,  0.92273091,
#          0.27933765,  0.80955838],
#        ...,
#        [ 0.0700174 ,  0.18520711,  0.26795417, ..., -0.59045052,
#         -0.47987484,  0.02359975],
#        [-0.40656829, -0.39930351, -0.43363918, ...,  0.16596699,
#          0.10375513, -0.24061267],
#        [ 0.66097961,  0.87237364,  0.9785134 , ..., -1.03635174,
#         -0.79123264, -1.889367  ]])

# %%
y_train
# Out:
# 13172    3
# 10172    3
# 10960    3
# 65       5
# 6400     4
#         ..
# 982      5
# 13414    3
# 10029    6
# 8008     6
# 4536     2
# Name: encoded_class, Length: 10208, dtype: int64

# %%
y_train_scaled = standard_scaler.fit_transform(y_train.values.reshape(-1,1))

# %%
y_train_scaled
# Out:
# array([[-0.28075744],
#        [-0.28075744],
#        [-0.28075744],
#        ...,
#        [ 1.35196492],
#        [ 1.35196492],
#        [-0.82499823]])

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()

# %%
X_train_normalized = Normalizer(X_train)
X_train_normalized
# Out:
# Normalizer(norm=        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 13172  38091    755.186       271.077683       179.756984      1.508023
# 10172  23980    575.605       204.749520       149.430765      1.370197
# 10960  28584    625.161       232.767486       156.572708      1.486642
# 65     32581    649.583       224.424178       184.923471      1.213606
# 6400   53174    904.614       361.914574       189.074605      1.914136
# ...      ...        ...              ...              ...           ...
# 982    39037    712.794       250.782231       198.444192      1.26...
# 10960     0.819585      0.008143      0.002267      0.671720      0.998607
# 65        0.907544      0.006888      0.002882      0.823636      0.999569
# 6400      0.718950      0.006806      0.001122      0.516889      0.989396
# ...            ...           ...           ...           ...           ...
# 982       0.888989      0.006424      0.002475      0.790302      0.998738
# ...

# %%
X_train
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 13172  38091    755.186       271.077683       179.756984      1.508023
# 10172  23980    575.605       204.749520       149.430765      1.370197
# 10960  28584    625.161       232.767486       156.572708      1.486642
# 65     32581    649.583       224.424178       184.923471      1.213606
# 6400   53174    904.614       361.914574       189.074605      1.914136
# ...      ...        ...              ...              ...           ...
# 982    39037    712.794       250.782231       198.444192      1.263742
# 13414  39814    740.266       278.435684       182.381665      1.526665
# 10029  55314    896.530       343.568669       205.981740      1.667957
# 8008   41201    770.513       283.139922       186.387386      1.519094
# 4536   72814   1044.679       404.769656       232.095506      1.743979
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
print(X_train_normalized)
# Out:
# Normalizer(norm=        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 13172  38091    755.186       271.077683       179.756984      1.508023
# 10172  23980    575.605       204.749520       149.430765      1.370197
# 10960  28584    625.161       232.767486       156.572708      1.486642
# 65     32581    649.583       224.424178       184.923471      1.213606
# 6400   53174    904.614       361.914574       189.074605      1.914136
# ...      ...        ...              ...              ...           ...
# 982    39037    712.794       250.782231       198.444192      1.26...
# 10960     0.819585      0.008143      0.002267      0.671720      0.998607
# 65        0.907544      0.006888      0.002882      0.823636      0.999569
# 6400      0.718950      0.006806      0.001122      0.516889      0.989396
# ...            ...           ...           ...           ...           ...
# 982       0.888989      0.006424      0.002475      0.790302      0.998738
# ...

# %%
encoded_class = ordinal_encoder.fit_transform(bean['Class'].values.reshape(-1,1))
encoded_class
# Out:
# array([[5.],
#        [5.],
#        [5.],
#        ...,
#        [3.],
#        [3.],
#        [3.]])

# %%
ordinal_encoder = OrdinalEncoder()

# %%
pip install --upgrade openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 3.1 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.0.10
#     Uninstalling openpyxl-3.0.10:
#       Successfully uninstalled openpyxl-3.0.10
# ...
# Note: you may need to restart the kernel to use updated packages.
