# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pandas import Series, DataFrame

# %%
df = pd.read_csv('/Users/anilthapa/Downloads/dataset_DT.csv')
df.head()
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0  34.0  blue-collar    single  secondary      no  13408.0      no   no
# 1  49.0   management  divorced   tertiary      no  20727.0      no   no
# 2  32.0     services    single   tertiary      no   1743.0     yes   no
# 3  46.0   management  divorced   tertiary      no  10469.0     yes   no
# 4  26.0   management    single   tertiary      no   7628.0      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular  1.0   apr     647.0       2.0   -1.0       0.0  unknown  no
# 1  cellular  1.0   apr     285.0       3.0  132.0       2.0  failure  no
# 2  cellular  1.0   apr    1156.0       1.0  261.0       3.0    other  no
# 3  cellular  1.0   apr     202.0       2.0   -1.0       0.0  unknown  no
# 4  cellular  1.0   apr     263.0       1.0   -1.0       0.0  unknown  no

# %%
df.shape
# Out:
# (18423, 17)

# %% [markdown]
# It appears that our data has 17 features, which is very high dimensional. The number of records is 18423, which is sufficient.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18423 entries, 0 to 18422
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        18423 non-null  float64
#  1   job        18423 non-null  object
#  2   marital    18423 non-null  object
#  3   education  18103 non-null  object
#  4   default    18423 non-null  object
#  5   balance    18423 non-null  float64
#  6   housing    18423 non-null  object
#  7   loan       18423 non-null  object
#  8   contact    18423 non-null  object
#  9   day        18117 non-null  float64
#  10  month      18109 non-null  object
#  11  duration   18423 non-null  float64
#  12  campaign   18423 non-null  float64
#  13  pdays      18423 non-null  float64
#  14  previous   18423 non-null  float64
#  15  poutcome   18423 non-null  object
#  16  y          18423 non-null  object
# dtypes: float64(7), object(10)
# memory usage: 2.4+ MB

# %%
df.isna().any()
# Out:
# age          False
# job          False
# marital      False
# education     True
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day           True
# month         True
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# y            False
# dtype: bool

# %% [markdown]
# #### It appears that three columns `education`, `day` & `month` has missing values.

# %%
df.marital.unique()
# Out:
# array(['single', 'divorced', 'married'], dtype=object)

# %%
df['marital'] = df['marital'].astype('category')

# %%
df.education.unique()
# Out:
# array(['secondary', 'tertiary', 'primary', 'unknown', nan], dtype=object)

# %%
df['job'].value_counts()
# Out:
# job
# management       4082
# blue-collar      3722
# technician       2949
# admin.           2012
# services         1582
# retired          1176
# self-employed     670
# entrepreneur      588
# unemployed        560
# student           507
# housemaid         463
# unknown           112
# Name: count, dtype: int64

# %%
df['job'] = df['job'].astype('category')

# %%
df['education'] = df['education'].astype('category')

# %%
df['default'] = df['default'].astype('category')

# %%
df['contact'] = df['contact'].astype('category')

# %%
df['housing'] = df['housing'].astype('category')

# %%
df['loan'] = df['loan'].astype('category')

# %%
df['contact'] = df['contact'].astype('category')

# %%
df['poutcome'] = df['poutcome'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18423 entries, 0 to 18422
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        18423 non-null  float64
#  1   job        18423 non-null  category
#  2   marital    18423 non-null  category
#  3   education  18103 non-null  category
#  4   default    18423 non-null  category
#  5   balance    18423 non-null  float64
#  6   housing    18423 non-null  category
#  7   loan       18423 non-null  category
#  8   contact    18423 non-null  category
#  9   day        18117 non-null  float64
#  10  month      18109 non-null  object
#  11  duration   18423 non-null  float64
#  12  campaign   18423 non-null  float64
#  13  pdays      18423 non-null  float64
#  14  previous   18423 non-null  float64
#  15  poutcome   18423 non-null  category
#  16  y          18423 non-null  object
# dtypes: category(8), float64(7), object(2)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  18423.000000   18423.000000  18117.000000  18423.000000  18423.000000
# mean      40.952451    1849.616403     15.252525    411.779569      2.279433
# std       11.458720    3742.556247      8.085925    323.241660      1.981642
# min       18.000000   -3372.000000      1.000000      5.000000      1.000000
# 25%       32.000000     206.000000      8.000000    192.000000      1.000000
# 50%       38.000000     718.000000     15.000000    316.000000      2.000000
# 75%       49.000000    2116.500000     21.000000    533.000000      3.000000
# max       95.000000  102127.000000     31.000000   3881.000000     55.000000
#
#               pdays      previous
# count  18423.000000  18423.000000
# mean      57.421213      0.875970
# std      112.455326      2.226526
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       91.000000      1.000000
# max      871.000000     58.000000

# %%
df.isna().any()
# Out:
# age          False
# job          False
# marital      False
# education     True
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day           True
# month         True
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# y            False
# dtype: bool

# %%
df.isna().sum()
# Out:
# age            0
# job            0
# marital        0
# education    320
# default        0
# balance        0
# housing        0
# loan           0
# contact        0
# day          306
# month        314
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# y              0
# dtype: int64

# %% [markdown]
# #### It appears that `education`, `day` and `month` do have missing values in the dataframe

# %%
df[df.isna().any(axis = 1)]
# Out:
#         age            job   marital  education default  balance housing loan  \
# 8      33.0         admin.    single  secondary      no    285.0     yes   no
# 57     44.0    blue-collar   married    primary      no    612.0     yes  yes
# 69     37.0     management   married   tertiary      no    489.0     yes   no
# 77     49.0     management   married        NaN      no    596.0     yes   no
# 88     41.0  self-employed   married        NaN      no   3123.0     yes   no
# ...     ...            ...       ...        ...     ...      ...     ...  ...
# 18324  41.0     management   married   tertiary      no      0.0      no   no
# 18380  32.0     management  divorced   tertiary      no    530.0     yes   no
# 18389  44.0     management   married        NaN      no   1036.0      no   no
# 18392  34.0     management   married        NaN      no    812.0      no   no
# 18393  72.0        retired   married    primary      no   4657.0      no   no
#
#         contact   day month  duration  campaign  pdays  previous poutcome    y
# 8      cellular   NaN   apr     427.0       1.0  329.0       1.0    other   no
# 57     cellular   3.0   NaN    1091.0       1.0  135.0       1.0  failure   no
# 69     cellular   NaN   apr     246.0       2.0  133.0       6.0  failure   no
# 77     cellular   3.0   apr     579.0       2.0   -1.0       0.0  unknown   no
# 88     cellular   3.0   apr    1203.0       2.0  135.0       2.0  failure  yes
# ...         ...   ...   ...       ...       ...    ...       ...      ...  ...
# 18324  cellular   NaN   sep     294.0       4.0   63.0      11.0    other  yes
# 18380  cellular  24.0   NaN      91.0       1.0  114.0       2.0  failure   no
# 18389  cellular  25.0   sep     491.0       1.0   -1.0       0.0  unknown   no
# 18392  cellular  27.0   sep     156.0       2.0  279.0       1.0  failure   no
# 18393  cellular   NaN   sep     132.0       4.0   94.0      16.0    other   no
#
# [922 rows x 17 columns]

# %%
df[df['education'].isna()]
# Out:
#         age            job  marital education default  balance housing loan  \
# 77     49.0     management  married       NaN      no    596.0     yes   no
# 88     41.0  self-employed  married       NaN      no   3123.0     yes   no
# 131    29.0     technician   single       NaN      no   1729.0     yes   no
# 211    42.0    blue-collar  married       NaN      no   3168.0     yes   no
# 368    40.0  self-employed  married       NaN      no  13669.0      no   no
# ...     ...            ...      ...       ...     ...      ...     ...  ...
# 18234  46.0    blue-collar  married       NaN      no    640.0     yes   no
# 18237  28.0    blue-collar   single       NaN      no    322.0      no   no
# 18277  32.0     technician   single       NaN      no   1855.0      no   no
# 18389  44.0     management  married       NaN      no   1036.0      no   no
# 18392  34.0     management  married       NaN      no    812.0      no   no
#
#          contact   day month  duration  campaign  pdays  previous poutcome  \
# 77      cellular   3.0   apr     579.0       2.0   -1.0       0.0  unknown
# 88      cellular   3.0   apr    1203.0       2.0  135.0       2.0  failure
# 131     cellular   6.0   apr     479.0       1.0   -1.0       0.0  unknown
# 211     cellular   8.0   apr     764.0       2.0   -1.0       0.0  unknown
# 368     cellular  14.0   apr     255.0       7.0   -1.0       0.0  unknown
# ...          ...   ...   ...       ...       ...    ...       ...      ...
# 18234   cellular  11.0   sep     108.0       2.0  129.0       2.0  failure
# 18237  telephone  11.0   sep     240.0       2.0   95.0       3.0    other
# 18277   cellular  15.0   sep     126.0       2.0  134.0       1.0    other
# 18389   cellular  25.0   sep     491.0       1.0   -1.0       0.0  unknown
# 18392   cellular  27.0   sep     156.0       2.0  279.0       1.0  failure
#
#          y
# 77      no
# 88     yes
# 131     no
# 211     no
# 368     no
# ...    ...
# 18234  yes
# 18237  yes
# 18277  yes
# 18389   no
# 18392   no
#
# [320 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18423 entries, 0 to 18422
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        18423 non-null  float64
#  1   job        18423 non-null  category
#  2   marital    18423 non-null  category
#  3   education  18103 non-null  category
#  4   default    18423 non-null  category
#  5   balance    18423 non-null  float64
#  6   housing    18423 non-null  category
#  7   loan       18423 non-null  category
#  8   contact    18423 non-null  category
#  9   day        18117 non-null  float64
#  10  month      18109 non-null  object
#  11  duration   18423 non-null  float64
#  12  campaign   18423 non-null  float64
#  13  pdays      18423 non-null  float64
#  14  previous   18423 non-null  float64
#  15  poutcome   18423 non-null  category
#  16  y          18423 non-null  object
# dtypes: category(8), float64(7), object(2)
# memory usage: 1.4+ MB

# %%
df.select_dtypes(['category'])
# Out:
#                 job   marital  education default housing loan    contact  \
# 0       blue-collar    single  secondary      no      no   no   cellular
# 1        management  divorced   tertiary      no      no   no   cellular
# 2          services    single   tertiary      no     yes   no   cellular
# 3        management  divorced   tertiary      no     yes   no   cellular
# 4        management    single   tertiary      no      no   no   cellular
# ...             ...       ...        ...     ...     ...  ...        ...
# 18418    technician   married  secondary      no      no   no   cellular
# 18419    management   married    unknown      no      no   no   cellular
# 18420   blue-collar   married  secondary      no      no   no   cellular
# 18421    technician    single  secondary      no      no   no  telephone
# 18422  entrepreneur   married  secondary      no      no   no  telephone
#
#       poutcome
# 0      unknown
# 1      failure
# 2        other
# 3      unknown
# 4      unknown
# ...        ...
# 18418    other
# 18419  unknown
# 18420  success
# 18421  unknown
# 18422  unknown
#
# [18423 rows x 8 columns]

# %%
df.dtypes
# Out:
# age           float64
# job          category
# marital      category
# education    category
# default      category
# balance       float64
# housing      category
# loan         category
# contact      category
# day           float64
# month          object
# duration      float64
# campaign      float64
# pdays         float64
# previous      float64
# poutcome     category
# y              object
# dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dec

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_gini = DecisionTreeClassifier(criterion='gini')

# %%
tree_entropy = DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# %%
fpr, tpr, thresholds = roc_curve(y_true, y_score)

roc_auc = roc_auc_score(y_true, y_score)

# %%
plt.figure()
plt.plot([0,1], [0,1], lw = 2)
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristics Curve')
plt.legend(loc ='lower right')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
