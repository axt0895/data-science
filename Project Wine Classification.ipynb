# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split

# %%
data  = pd.read_csv('/Users/anilthapa/Downloads/winequality-white.csv', sep =';')
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
#Checking null values in the data frame
data.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
X = data.loc[:,'fixed acidity':'alcohol']
y = data['quality']

# %%
#our output
data['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
data.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (10,8))
sns.heatmap(data.corr(), annot = True, cmap ='Blues')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data.corr(), kind = 'kde')

# %%
sns.boxplot(x = data['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity'>

# %%
sns.displot(data['fixed acidity'], kind = 'kde')

# %%
sns.jointplot(x = data['density'], y = data['alcohol'], kind ='kde')

# %%
sns.histplot(data, x = data['alcohol'], bins = 30)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>
